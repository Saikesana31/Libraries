# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
data = load_iris()

X,y = data.data,data.target #Assigning the data to 2 variables where X = input  and y =  target

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size   = 0.2) #Here 80% training and 20% testing

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
counts = np.bincount(y_train)
positions = np.arange(3)

# %%
counts
# Out:
# array([40, 42, 38])

# %%
positions
# Out:
# array([0, 1, 2])

# %%
plt.bar(positions,counts)
plt.xticks(positions,data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x1c439478050>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
##here we wii be doing equal distribution
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1,test_size = 0.2)



for train_idx,test_idx in split.split(X,y):
    X_train,X_test = X[train_idx],X[test_idx]
    y_train,y_test = y[train_idx],y[test_idx]

# %%
counts = np.bincount(y_train)
position = np.arange(3)

print(counts)

plt.bar(positions,counts)
plt.xticks(positions,data.target_names)
# Out:
# [40 40 40]
# ([<matplotlib.axis.XTick at 0x1c43b58bd90>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])
