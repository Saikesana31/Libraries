# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
X, _ = make_blobs(n_samples=5000, centers  = 5, random_state=10)

# %%
X
# Out:
# array([[  6.17306585, -10.25446247],
#        [ -8.13981972,   4.45135687],
#        [  2.71307241,   4.32686739],
#        ...,
#        [ -6.91896111,   4.29323728],
#        [ -3.95595105,   4.23150467],
#        [  0.91461712,  -7.45569288]], shape=(5000, 2))

# %%
scaler = StandardScaler()

X_scale = scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[ 1.46759032, -1.17339025],
#        [-1.498761  ,  1.08891269],
#        [ 0.75050528,  1.06976157],
#        ...,
#        [-1.24573756,  1.06458801],
#        [-0.63165253,  1.05509123],
#        [ 0.3777747 , -0.74283521]], shape=(5000, 2))

# %%
import matplotlib.pyplot as  plt


plt.scatter(X_scale[:,0],X_scale[:,1])

# %%
kmeans = KMeans(n_clusters=5)


kmeans.fit(X_scale)
# Out:
# KMeans(n_clusters=5)

# %%
plt.scatter(X_scale[:,0],X_scale[:,1],c = kmeans.labels_)

# %%
from sklearn.datasets import make_moons

# %%
X,_ = make_moons(n_samples=5000,noise=0.01)

scaler = StandardScaler()

X_scale = scaler.fit_transform(X)

# %%
plt.scatter(X_scale[:,0],X_scale[:,1])

# %%
kmeans = KMeans(n_clusters = 2)

kmeans.fit(X_scale)
# Out:
# KMeans(n_clusters=2)

# %%
plt.scatter(X_scale[:,0],X_scale[:,1],c= kmeans.labels_)

# %% [markdown]
# ### DBscan

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps = 0.2)

# %%
dbscan.fit(X_scale)
# Out:
# DBSCAN(eps=0.2)

# %%
plt.scatter(X_scale[:,0],X_scale[:,1],c= dbscan.labels_)
